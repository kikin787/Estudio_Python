# %%
import random
import math
import statistics

# Datos del problema
num_procesadores = 8

# Calcular el número mínimo de bits necesarios para representar el número de procesadores
num_bits_por_carga = math.ceil(math.log2(num_procesadores))

# Generar cargas aleatorias hasta que la suma total sea 3600
cargas = []
suma_cargas = 0
while suma_cargas < 3600:
    carga = random.randint(50, 100)
    if suma_cargas + carga > 3600:
        carga = 3600 - suma_cargas
    cargas.append(carga)
    suma_cargas += carga

num_cargas = len(cargas)

# %%
# Función para calcular la distribución de cargas
def calcular_distribucion_de_cargas(asignacion):
    cargas_por_procesador = [0] * num_procesadores
    for i in range(num_cargas):
        carga = cargas[i]
        procesador = int(asignacion[i * num_bits_por_carga:(i + 1) * num_bits_por_carga], 2)
        if procesador < num_procesadores:  # Asegurarse de que el procesador esté dentro del rango válido
            cargas_por_procesador[procesador] += carga
    return cargas_por_procesador

# %%
# Función para generar una asignación aleatoria de cargas
def generar_asignacion_aleatoria():
    return ''.join([format(random.randint(0, num_procesadores - 1), '0' + str(num_bits_por_carga) + 'b') for _ in
                    range(num_cargas)])

# %%
# Función para calcular la aptitud de una asignación
def calcular_fitness(asignacion):
    # Calcular la distribución de cargas
    distribucion_de_cargas = calcular_distribucion_de_cargas(asignacion)
    # Calcular la desviación estándar de las cargas
    desviacion_estandar = statistics.stdev(distribucion_de_cargas)
    return desviacion_estandar

# %%
# Función para mutar una asignación
def mutar(asignacion):
    indice = random.randint(0, len(asignacion) - 1)
    bit = asignacion[indice]
    bit_mutado = '1' if bit == '0' else '0'
    return asignacion[:indice] + bit_mutado + asignacion[indice + 1:]

# %%
# Función para seleccionar una asignación usando selección por ruleta
def seleccionar(asignaciones, fitnesses):
    total_fitness = sum(fitnesses)
    pesos = [fitness / total_fitness for fitness in fitnesses]
    return random.choices(asignaciones, weights=pesos, k=1)[0]

# %%
# Función para cruzar dos asignaciones
def cruzar(asignacion1, asignacion2):
    punto_de_cruce = random.randint(1, len(asignacion1) - 1)
    hijo1 = asignacion1[:punto_de_cruce] + asignacion2[punto_de_cruce:]
    hijo2 = asignacion2[:punto_de_cruce] + asignacion1[punto_de_cruce:]
    return hijo1, hijo2

# %%
# Generar una población inicial de asignaciones aleatorias
poblacion = [generar_asignacion_aleatoria() for _ in range(100)]

# Ejecutar el algoritmo genético
for generacion in range(100):
    # Calcular la aptitud de cada asignación en la población
    fitnesses = [calcular_fitness(asignacion) for asignacion in poblacion]

    # Seleccionar dos padres usando selección por ruleta
    padre1 = seleccionar(poblacion, fitnesses)
    padre2 = seleccionar(poblacion, fitnesses)

    # Cruzar los padres para generar dos hijos
    hijo1, hijo2 = cruzar(padre1, padre2)

    # Mutar los hijos con una pequeña probabilidad
    if random.random() < 0.01:
        hijo1 = mutar(hijo1)
    if random.random() < 0.01:
        hijo2 = mutar(hijo2)

    # Reemplazar dos asignaciones aleatorias en la población por los nuevos hijos
    poblacion[random.randint(0, len(poblacion) - 1)] = hijo1
    poblacion[random.randint(0, len(poblacion) - 1)] = hijo2

    # Encontrar la mejor asignación en la población actual
    mejor_asignacion = min(poblacion, key=calcular_fitness)

    # Calcular la distribución de cargas
    distribucion_de_cargas = calcular_distribucion_de_cargas(mejor_asignacion)

    # Mostrar la distribución de cargas
    print(f"\nGeneración {generacion + 1}:")
    for i, carga_por_procesador in enumerate(distribucion_de_cargas):
        print(f"Procesador {i} = {carga_por_procesador} total de cargas")

    carga_maxima = max(distribucion_de_cargas)
    carga_media = sum(distribucion_de_cargas) / num_procesadores
    print(f"Carga máxima de procesador = {carga_maxima}")
    print(f"Carga media = {carga_media}")

# Mostrar la mejor asignación y su aptitud
print(f"\nMejor asignación: {mejor_asignacion}")
print(f"Aptitud de la mejor asignación: {calcular_fitness(mejor_asignacion)}")
# Out:
# Generación 1:
# Procesador 0 = 587 total de cargas
# Procesador 1 = 506 total de cargas
# Procesador 2 = 512 total de cargas
# Procesador 3 = 340 total de cargas
# Procesador 4 = 357 total de cargas
# Procesador 5 = 357 total de cargas
# Procesador 6 = 435 total de cargas
# Procesador 7 = 506 total de cargas
# Carga máxima de procesador = 587
# Carga media = 450.0
#
# Generación 2:
# Procesador 0 = 587 total de cargas
# Procesador 1 = 506 total de cargas
# Procesador 2 = 512 total de cargas
# Procesador 3 = 340 total de cargas
# Procesador 4 = 357 total de cargas
# Procesador 5 = 357 total de cargas
# Procesador 6 = 435 total de cargas
# Procesador 7 = 506 total de cargas
# Carga máxima de procesador = 587
# Carga media = 450.0
#
# Generación 3:
# Procesador 0 = 587 total de cargas
# Procesador 1 = 506 total de cargas
# Procesador 2 = 512 total de cargas
# Procesador 3 = 340 total de cargas
# Procesador 4 = 357 total de cargas
# Procesador 5 = 357 total de cargas
# Procesador 6 = 435 total de cargas
# Procesador 7 = 506 total de cargas
# Carga máxima de procesador = 587
# Carga media = 450.0
#
# Generación 4:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 5:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 6:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 7:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 8:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 9:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 10:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 11:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 12:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 13:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 14:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 15:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 16:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 17:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 18:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 19:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 20:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 21:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 22:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 23:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 24:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 25:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 26:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 27:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 28:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 29:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 30:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 31:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 32:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 33:
# Procesador 0 = 417 total de cargas
# Procesador 1 = 393 total de cargas
# Procesador 2 = 555 total de cargas
# Procesador 3 = 447 total de cargas
# Procesador 4 = 379 total de cargas
# Procesador 5 = 299 total de cargas
# Procesador 6 = 568 total de cargas
# Procesador 7 = 542 total de cargas
# Carga máxima de procesador = 568
# Carga media = 450.0
#
# Generación 34:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 35:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 36:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 37:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 38:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 39:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 40:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 41:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 42:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 43:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 44:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 45:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 46:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 47:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 48:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 49:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 50:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 51:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 52:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 53:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 54:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 55:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 56:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 57:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 58:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 59:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 60:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 61:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 62:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 63:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 64:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 65:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 66:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 67:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 68:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 69:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 70:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 71:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 72:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 73:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 74:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 75:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 76:
# Procesador 0 = 582 total de cargas
# Procesador 1 = 325 total de cargas
# Procesador 2 = 342 total de cargas
# Procesador 3 = 450 total de cargas
# Procesador 4 = 447 total de cargas
# Procesador 5 = 483 total de cargas
# Procesador 6 = 483 total de cargas
# Procesador 7 = 488 total de cargas
# Carga máxima de procesador = 582
# Carga media = 450.0
#
# Generación 77:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 78:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 79:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 80:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 81:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 82:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 83:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 84:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 85:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 86:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 87:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 88:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 89:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 90:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 91:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 92:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 93:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 94:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 95:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 96:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 97:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 98:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 99:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Generación 100:
# Procesador 0 = 519 total de cargas
# Procesador 1 = 464 total de cargas
# Procesador 2 = 432 total de cargas
# Procesador 3 = 622 total de cargas
# Procesador 4 = 354 total de cargas
# Procesador 5 = 419 total de cargas
# Procesador 6 = 304 total de cargas
# Procesador 7 = 486 total de cargas
# Carga máxima de procesador = 622
# Carga media = 450.0
#
# Mejor asignación: 010011100101001000111010101000001011110010001110000010101000000011101100011111101001100000110001011111111100000011110011001111011010111101
# Aptitud de la mejor asignación: 98.31000530392186
