# %%
import random
import matplotlib.pyplot as plt
import pandas as pd

def cargas(sumaFinal, tamaño_ventana):
    numeros_random = []
    suma = 0
    while suma < sumaFinal:
        numeroA = random.randint(5, 15)
        if suma + numeroA > sumaFinal:
            numeros_random.append(sumaFinal - suma)
            break
        else:
            numeros_random.append(numeroA)
            suma = sum(numeros_random)
    if len(numeros_random) % tamaño_ventana != 0:
        resto = len(numeros_random) % tamaño_ventana
        if resto != 0:
            elementos_faltantes = tamaño_ventana - resto
            numeros_random.extend([0] * elementos_faltantes)
    return numeros_random

def generar_poblacion(num_individuos, tamaño_ventana):
    poblacion = []
    for _ in range(num_individuos):
        individuo = [random.uniform(1, tamaño_ventana) for _ in range(tamaño_ventana)]
        poblacion.append(individuo)
    return poblacion

def calcular_fitness(asignacion_procesos, maxspan):
    utilizacion_procesadores = []
    for procesos in asignacion_procesos.values():
        carga_total = sum(procesos)
        utilizacion = carga_total / maxspan
        utilizacion_procesadores.append(utilizacion)

    apu = sum(utilizacion_procesadores) / len(utilizacion_procesadores)
    fitness = (1 / maxspan) * apu
    return fitness

def seleccion_por_ruleta(poblacion, fitness_poblacion):
    total_fitness = sum(fitness_poblacion)
    probabilidad_seleccion = [fit / total_fitness for fit in fitness_poblacion]
    papa1 = random.choices(poblacion, weights=probabilidad_seleccion)[0]
    papa2 = random.choices(poblacion, weights=probabilidad_seleccion)[0]
    return papa1, papa2

def mutacion(individuo, tasa_mut):
    if random.random() < tasa_mut:
        idx1, idx2 = random.sample(range(len(individuo)), 2)
        individuo[idx1], individuo[idx2] = individuo[idx2], individuo[idx1]
    return individuo


def cruzamiento(papa1, papa2, tasa_cruz, tasa_mut):
    if random.random() < tasa_cruz:
        punto_de_cruce = random.randint(1, len(papa1) - 1)

        hijo1 = papa1[:punto_de_cruce] + [x for x in papa2 if x not in papa1[:punto_de_cruce]]
        hijo2 = papa2[:punto_de_cruce] + [x for x in papa1 if x not in papa2[:punto_de_cruce]]
    else:
        hijo1 = papa1
        hijo2 = papa2

    return mutacion(hijo1, tasa_mut), mutacion(hijo2, tasa_mut)


def conversion(individuo, carga, tamaño_ventana, num_procesadores):
    asignacion_procesos = {i + 1: [] for i in range(num_procesadores)}
    indices = list(map(int, individuo))  # No se usa split() porque `individuo` es una lista
    x = 0
    while x < len(carga):
        for i, indice in enumerate(indices):
            clave = (i % num_procesadores) + 1
            asignacion_procesos[clave].append(carga[(indice - 1) + x])
        x = x + tamaño_ventana
    maxspan = max(sum(procesos) for procesos in asignacion_procesos.values())
    fitness = calcular_fitness(asignacion_procesos, maxspan)
    return asignacion_procesos, fitness

def slide_window(procesos, size_w):
    ventanas = []
    for i in range(0, len(procesos), size_w):
        ventana = procesos[i:i + size_w]
        if len(ventana) < size_w:
            ventana += [0] * (size_w - len(ventana))
        ventanas.append(ventana)
    return ventanas

def calcular_estadisticas_procesadores(asignacion_procesos):
    colas_procesadores = [procesos for procesos in asignacion_procesos.values()]
    media_procesadores = sum(map(sum, colas_procesadores)) / len(colas_procesadores)
    max_cola = max(sum(procesos) for procesos in asignacion_procesos.values())
    return colas_procesadores, media_procesadores, max_cola

def imprimir_colas_procesadores(colas_procesadores):
    for i, cola in enumerate(colas_procesadores):
        print(f"Procesador {i} = {sum(cola)}")
def distribuir_con_slide_window():
    num_twits = 3600
    num_procesadores = 8
    tamaño_ventana = num_procesadores * 2
    num_individuos = 10
    num_generaciones = 50
    tasa_mut = 0.1
    tasa_cruz = 0.8

    while num_procesadores <= 8:
        carga = cargas(num_twits, tamaño_ventana)

        for generacion in range(num_generaciones):
            poblacion = generar_poblacion(num_individuos, tamaño_ventana)
            mejor_asignacion_procesos = None
            mejor_carga_actual = float('-inf')
            nueva = None

            for individuo in poblacion:
                asignacion, _ = conversion(individuo, carga, tamaño_ventana, num_procesadores)
                carga_procesadores = [sum(procesos) for procesos in asignacion.values()]
                max_carga_procesador = max(carga_procesadores)

                if max_carga_procesador > mejor_carga_actual:
                    mejor_carga_actual = max_carga_procesador
                    mejor_asignacion_procesos = asignacion.copy()
                    nueva = individuo

            print(f"\nGeneración: {generacion + 1}")
            print("Detalles de la asignación de procesos:")
            for i, procesos in mejor_asignacion_procesos.items():
                print(f"Procesador {i} = {sum(procesos)}")
            print(f"Media de las cargas de procesadores: {sum(carga_procesadores) / len(carga_procesadores)}")
            print(f"Mejor carga encontrada: {mejor_carga_actual}")
            print(f"Nueva población: {nueva}")

            nueva_poblacion = []

            for _ in range(num_individuos):
                if random.random() < tasa_cruz:
                    papa1, papa2 = seleccion_por_ruleta(poblacion, [1] * num_individuos)
                    hijo1, hijo2 = cruzamiento(papa1, papa2, tasa_cruz, tasa_mut)
                    nueva_poblacion.extend([hijo1, hijo2])

                nueva_poblacion.append(mutacion(nueva, tasa_mut))

            poblacion = nueva_poblacion

        num_procesadores += 1

distribuir_con_slide_window()
# Out:
# Generación: 1
# Detalles de la asignación de procesos:
# Procesador 1 = 455
# Procesador 2 = 470
# Procesador 3 = 482
# Procesador 4 = 453
# Procesador 5 = 423
# Procesador 6 = 438
# Procesador 7 = 445
# Procesador 8 = 413
# Media de las cargas de procesadores: 450.625
# Mejor carga encontrada: 482
# Nueva población: [7.3100110732727135, 14.639274564634572, 2.693615435726301, 3.7891119057343516, 15.591567733326585, 8.882456413557065, 2.611358746756281, 4.670673700620501, 5.270594899632162, 11.668652658468364, 11.863715520107425, 10.990041528882399, 8.054219309256975, 7.345796920718318, 1.5828806931277657, 1.7869174293022692]
#
# Generación: 2
# Detalles de la asignación de procesos:
# Procesador 1 = 484
# Procesador 2 = 465
# Procesador 3 = 447
# Procesador 4 = 445
# Procesador 5 = 468
# Procesador 6 = 438
# Procesador 7 = 436
# Procesador 8 = 450
# Media de las cargas de procesadores: 454.0
# Mejor carga encontrada: 484
# Nueva población: [11.08770406988583, 13.787856148081154, 1.4487933817458778, 5.17830628540517, 2.834296649749103, 7.286799812974431, 14.384563213350514, 4.50476557381422, 11.072624431934216, 12.711375088319018, 12.206296091443996, 8.59849239887846, 14.800792519968311, 8.031629722754491, 4.343822031833481, 11.88424113289924]
#
# Generación: 3
# Detalles de la asignación de procesos:
# Procesador 1 = 484
# Procesador 2 = 480
# Procesador 3 = 416
# Procesador 4 = 447
# Procesador 5 = 436
# Procesador 6 = 447
# Procesador 7 = 447
# Procesador 8 = 465
# Media de las cargas de procesadores: 449.5
# Mejor carga encontrada: 484
# Nueva población: [11.642541840680835, 11.414140804570486, 4.2154239939233396, 1.4321736141694483, 8.789887824828913, 12.933687453440053, 6.591310284085454, 12.85659015820437, 12.947132252407089, 6.808177222663714, 4.979853170168242, 11.824540251563686, 3.8569838559234144, 1.922076492655115, 15.661563218034598, 13.48178275804825]
#
# Generación: 4
# Detalles de la asignación de procesos:
# Procesador 1 = 463
# Procesador 2 = 417
# Procesador 3 = 484
# Procesador 4 = 436
# Procesador 5 = 461
# Procesador 6 = 432
# Procesador 7 = 466
# Procesador 8 = 431
# Media de las cargas de procesadores: 445.0
# Mejor carga encontrada: 484
# Nueva población: [13.392182865822898, 4.183525981437499, 11.19818047055119, 3.417068348541149, 13.886739343054314, 7.04165597747076, 9.55553696861916, 4.591872732509483, 2.9136707560696946, 15.571731927290426, 12.41611272872109, 8.469991063137734, 6.041941086104767, 4.472688524645732, 11.5632466196638, 13.253742034262372]
#
# Generación: 5
# Detalles de la asignación de procesos:
# Procesador 1 = 436
# Procesador 2 = 473
# Procesador 3 = 465
# Procesador 4 = 482
# Procesador 5 = 464
# Procesador 6 = 446
# Procesador 7 = 484
# Procesador 8 = 473
# Media de las cargas de procesadores: 439.625
# Mejor carga encontrada: 484
# Nueva población: [10.96481822008359, 11.454019832527164, 13.549551742333906, 2.162343803442607, 7.992791169376789, 6.23145294279669, 11.903003830673292, 12.644127309917673, 1.2716070987256498, 5.072187099879107, 11.811735159868833, 12.669396721948807, 2.80551425885034, 4.325282574598627, 12.545244534118813, 10.137661576684089]
#
# Generación: 6
# Detalles de la asignación de procesos:
# Procesador 1 = 422
# Procesador 2 = 422
# Procesador 3 = 482
# Procesador 4 = 459
# Procesador 5 = 453
# Procesador 6 = 464
# Procesador 7 = 464
# Procesador 8 = 445
# Media de las cargas de procesadores: 445.5
# Mejor carga encontrada: 482
# Nueva población: [4.934123579783856, 4.476099168406842, 2.814669680695333, 14.360860504480224, 5.450203320836996, 3.660675391222334, 3.3132099618935467, 13.489138306385117, 8.1686719493477, 8.273858064375313, 11.629156050600729, 10.297177672804823, 3.58264891094707, 11.28958998895649, 12.618830305993017, 3.417532319922164]
#
# Generación: 7
# Detalles de la asignación de procesos:
# Procesador 1 = 429
# Procesador 2 = 462
# Procesador 3 = 452
# Procesador 4 = 462
# Procesador 5 = 465
# Procesador 6 = 432
# Procesador 7 = 454
# Procesador 8 = 484
# Media de las cargas de procesadores: 451.375
# Mejor carga encontrada: 484
# Nueva población: [1.0257757228464683, 6.9465221747336185, 8.230833731181155, 6.726655961699453, 11.10503172416033, 7.836150210478681, 13.850416263483146, 11.021815245428142, 7.997702924199005, 7.06852885168165, 6.130424961514999, 7.056224564950014, 13.144603989511916, 4.829813252009383, 5.169832723971886, 12.279685673941602]
#
# Generación: 8
# Detalles de la asignación de procesos:
# Procesador 1 = 445
# Procesador 2 = 445
# Procesador 3 = 445
# Procesador 4 = 436
# Procesador 5 = 484
# Procesador 6 = 480
# Procesador 7 = 442
# Procesador 8 = 447
# Media de las cargas de procesadores: 458.0
# Mejor carga encontrada: 484
# Nueva población: [1.1331009330731348, 8.765873282557903, 8.716848278409568, 1.8652876899170103, 12.275763601793694, 6.860751606656469, 8.281984054431721, 13.157149783303616, 2.54440683096645, 10.466109825516206, 5.702823276061307, 10.490490399521544, 12.870976921908554, 11.802605941402058, 14.539174527929921, 9.122447931983183]
#
# Generación: 9
# Detalles de la asignación de procesos:
# Procesador 1 = 450
# Procesador 2 = 440
# Procesador 3 = 484
# Procesador 4 = 455
# Procesador 5 = 450
# Procesador 6 = 440
# Procesador 7 = 469
# Procesador 8 = 416
# Media de las cargas de procesadores: 439.375
# Mejor carga encontrada: 484
# Nueva población: [11.853469099976484, 15.880628280140854, 11.012206688426136, 7.682690280571503, 4.067503867584245, 5.042522083106714, 6.228224413119836, 4.453945082012875, 4.231378876601941, 10.038160465326248, 12.483804004854814, 5.168793373962642, 11.564754421322153, 15.26868335525129, 10.978052922928535, 4.672324106124913]
#
# Generación: 10
# Detalles de la asignación de procesos:
# Procesador 1 = 465
# Procesador 2 = 436
# Procesador 3 = 464
# Procesador 4 = 450
# Procesador 5 = 439
# Procesador 6 = 455
# Procesador 7 = 484
# Procesador 8 = 430
# Media de las cargas de procesadores: 447.625
# Mejor carga encontrada: 484
# Nueva población: [13.745773270263488, 5.406326058786382, 3.9585176668675928, 11.571117608013141, 10.015698529240424, 10.457681894944859, 12.849515348754247, 4.709614628217114, 12.030560554879186, 1.6031928138603049, 12.081670337221018, 4.335660530579053, 4.32523140218391, 7.6374397553462225, 11.476540343657522, 3.780118504869258]
#
# Generación: 11
# Detalles de la asignación de procesos:
# Procesador 1 = 440
# Procesador 2 = 428
# Procesador 3 = 416
# Procesador 4 = 482
# Procesador 5 = 432
# Procesador 6 = 439
# Procesador 7 = 454
# Procesador 8 = 484
# Media de las cargas de procesadores: 445.25
# Mejor carga encontrada: 484
# Nueva población: [10.833329585930342, 1.8985351113319977, 4.87439721404366, 2.9460148911290336, 13.769368743779568, 4.378912017517851, 13.434765787280208, 11.162928661815622, 15.113813363982768, 13.570517129922624, 4.961126305600278, 11.912138215678823, 15.46312531332952, 10.579845483047082, 10.003472332637084, 11.566944895271735]
#
# Generación: 12
# Detalles de la asignación de procesos:
# Procesador 1 = 436
# Procesador 2 = 484
# Procesador 3 = 451
# Procesador 4 = 455
# Procesador 5 = 444
# Procesador 6 = 455
# Procesador 7 = 449
# Procesador 8 = 466
# Media de las cargas de procesadores: 467.25
# Mejor carga encontrada: 484
# Nueva población: [4.53986567545647, 11.879527401520008, 11.292588537169436, 5.7102390721938745, 3.5670384033521487, 9.478721710534877, 2.799766965383363, 12.369151211685157, 14.977858841921394, 11.157296861211522, 15.05383068718322, 9.791769418136244, 3.485486716114256, 5.017169022468648, 15.411114001912486, 9.922174630837802]
#
# Generación: 13
# Detalles de la asignación de procesos:
# Procesador 1 = 446
# Procesador 2 = 462
# Procesador 3 = 470
# Procesador 4 = 473
# Procesador 5 = 436
# Procesador 6 = 431
# Procesador 7 = 445
# Procesador 8 = 484
# Media de las cargas de procesadores: 448.0
# Mejor carga encontrada: 484
# Nueva población: [9.08658749443136, 6.2072269198023395, 14.49221032621575, 12.011973511126625, 5.618395413188836, 15.822299206420436, 3.8386990965463514, 12.097039392022808, 3.911874131554208, 7.020110759342048, 11.346257325504034, 10.318178351217238, 1.9525440379692562, 3.497822679417962, 13.657981265158801, 12.983008424851148]
#
# Generación: 14
# Detalles de la asignación de procesos:
# Procesador 1 = 413
# Procesador 2 = 450
# Procesador 3 = 431
# Procesador 4 = 445
# Procesador 5 = 465
# Procesador 6 = 466
# Procesador 7 = 459
# Procesador 8 = 484
# Media de las cargas de procesadores: 451.0
# Mejor carga encontrada: 484
# Nueva población: [1.029653025463111, 3.945286724997172, 13.990471456015065, 3.2701393852618357, 12.453104233826304, 11.83167553180749, 10.666266217881612, 11.493889923187583, 4.950137223201623, 14.63340531282994, 4.8816522933222535, 13.942206976683943, 13.30307391940851, 9.323360811962518, 14.15851468285115, 12.857570006430544]
#
# Generación: 15
# Detalles de la asignación de procesos:
# Procesador 1 = 462
# Procesador 2 = 484
# Procesador 3 = 470
# Procesador 4 = 451
# Procesador 5 = 462
# Procesador 6 = 456
# Procesador 7 = 462
# Procesador 8 = 464
# Media de las cargas de procesadores: 441.25
# Mejor carga encontrada: 484
# Nueva población: [7.798831660151353, 11.415129818344727, 12.40481755956572, 15.64250345566933, 10.175355272746547, 8.200532820343046, 9.861232562988002, 7.993587490842237, 6.400549552647147, 11.730235329926131, 14.495793447987566, 11.975978728656601, 5.286282127430995, 12.517741143699856, 6.094797474655942, 2.5037229713328797]
#
# Generación: 16
# Detalles de la asignación de procesos:
# Procesador 1 = 452
# Procesador 2 = 452
# Procesador 3 = 446
# Procesador 4 = 461
# Procesador 5 = 419
# Procesador 6 = 459
# Procesador 7 = 455
# Procesador 8 = 484
# Media de las cargas de procesadores: 452.125
# Mejor carga encontrada: 484
# Nueva población: [6.569950908339141, 7.7699242790837, 6.32602387679437, 13.38418559263222, 8.114369128800735, 5.255296906737925, 5.989601224151622, 11.97481189611397, 8.519340931149639, 14.578387096269754, 4.777843480729473, 6.02904597756984, 1.215127145990028, 14.51494093781932, 9.324235693902825, 12.026642316749866]
#
# Generación: 17
# Detalles de la asignación de procesos:
# Procesador 1 = 433
# Procesador 2 = 482
# Procesador 3 = 417
# Procesador 4 = 484
# Procesador 5 = 473
# Procesador 6 = 464
# Procesador 7 = 418
# Procesador 8 = 468
# Media de las cargas de procesadores: 443.0
# Mejor carga encontrada: 484
# Nueva población: [15.636393541940322, 11.6223610861333, 4.663835590402795, 11.828059510979472, 10.898940555997395, 2.8910156854136764, 15.237563141764097, 14.816429332515709, 9.199644394733042, 2.260908372125558, 15.450107447732506, 11.95740416010156, 11.714783307610107, 9.09244244148508, 15.663643830462492, 2.695211901135089]
#
# Generación: 18
# Detalles de la asignación de procesos:
# Procesador 1 = 456
# Procesador 2 = 433
# Procesador 3 = 442
# Procesador 4 = 468
# Procesador 5 = 484
# Procesador 6 = 410
# Procesador 7 = 428
# Procesador 8 = 433
# Media de las cargas de procesadores: 451.625
# Mejor carga encontrada: 484
# Nueva población: [12.841888392717856, 15.250852342536241, 8.828214548180107, 2.409035165730912, 11.42623046177653, 1.6854004562890803, 8.948051166854194, 1.9243126997902895, 8.86377920699907, 9.941623586556512, 14.171403702689112, 14.596443959696076, 11.24774165025062, 1.6239663658521795, 8.257117987893674, 14.38523420351474]
#
# Generación: 19
# Detalles de la asignación de procesos:
# Procesador 1 = 466
# Procesador 2 = 452
# Procesador 3 = 464
# Procesador 4 = 428
# Procesador 5 = 470
# Procesador 6 = 482
# Procesador 7 = 465
# Procesador 8 = 445
# Media de las cargas de procesadores: 447.75
# Mejor carga encontrada: 482
# Nueva población: [9.378458069302136, 7.743685262629565, 7.895991752337708, 13.991941646328966, 14.233583912028788, 11.29023641629147, 13.034716357864623, 8.96327160098056, 12.660793023347894, 14.333490820536406, 2.6496137084110285, 1.148264144996964, 12.458604888557023, 2.318340966173693, 11.206938538444788, 10.621460183447649]
#
# Generación: 20
# Detalles de la asignación de procesos:
# Procesador 1 = 471
# Procesador 2 = 427
# Procesador 3 = 450
# Procesador 4 = 482
# Procesador 5 = 460
# Procesador 6 = 450
# Procesador 7 = 428
# Procesador 8 = 428
# Media de las cargas de procesadores: 457.125
# Mejor carga encontrada: 482
# Nueva población: [2.514712915524324, 3.4328715060823223, 4.961431731186428, 2.8879393100897044, 3.0383866724548154, 3.994917334235345, 13.327497888242856, 8.730765731438545, 5.211375019442757, 1.4112573385399871, 11.56154088407499, 12.225846106659198, 6.152998007248655, 14.927575154991832, 1.9584260247219163, 8.434746283057834]
#
# Generación: 21
# Detalles de la asignación de procesos:
# Procesador 1 = 431
# Procesador 2 = 484
# Procesador 3 = 455
# Procesador 4 = 470
# Procesador 5 = 465
# Procesador 6 = 446
# Procesador 7 = 476
# Procesador 8 = 446
# Media de las cargas de procesadores: 445.25
# Mejor carga encontrada: 484
# Nueva población: [4.6479066006621474, 11.031690866851713, 5.508260648503314, 14.363350784483982, 13.946631394638587, 4.674886607863703, 6.806476489985784, 3.485467446883897, 13.336116196873775, 12.111954606091956, 9.20347861558345, 11.962103648618271, 11.017554922550694, 6.287038459405769, 6.059985214425464, 7.69829605771157]
#
# Generación: 22
# Detalles de la asignación de procesos:
# Procesador 1 = 430
# Procesador 2 = 480
# Procesador 3 = 432
# Procesador 4 = 454
# Procesador 5 = 442
# Procesador 6 = 482
# Procesador 7 = 462
# Procesador 8 = 465
# Media de las cargas de procesadores: 446.0
# Mejor carga encontrada: 482
# Nueva población: [4.165965702403229, 12.670676013230453, 4.3210517955048875, 5.97344309838555, 8.151376610788795, 2.3371202593525955, 5.527877668124561, 13.667467135178528, 3.71407595410032, 6.748270934782354, 7.214180755841427, 13.957227035612096, 14.192840307636311, 11.729569687533642, 5.440656223659875, 11.159064612420343]
#
# Generación: 23
# Detalles de la asignación de procesos:
# Procesador 1 = 482
# Procesador 2 = 450
# Procesador 3 = 466
# Procesador 4 = 459
# Procesador 5 = 447
# Procesador 6 = 437
# Procesador 7 = 447
# Procesador 8 = 437
# Media de las cargas de procesadores: 454.875
# Mejor carga encontrada: 482
# Nueva población: [11.52273538780099, 11.342376286702509, 7.3612757281943555, 10.160140387533643, 12.385258571275303, 13.86866716011539, 6.262619000977541, 13.693588095362058, 2.28879510712667, 4.808589856101267, 11.004407678577916, 14.50682091581401, 1.0776238476923063, 8.165803177803104, 15.28962947361998, 8.594012342059312]
#
# Generación: 24
# Detalles de la asignación de procesos:
# Procesador 1 = 456
# Procesador 2 = 478
# Procesador 3 = 464
# Procesador 4 = 445
# Procesador 5 = 484
# Procesador 6 = 446
# Procesador 7 = 443
# Procesador 8 = 469
# Media de las cargas de procesadores: 444.875
# Mejor carga encontrada: 484
# Nueva población: [8.087735014804032, 2.964416107667053, 9.258435070321365, 13.949353229876444, 12.228026792321188, 6.068779173798318, 1.1343245465643217, 10.100263182474393, 11.503005299057735, 6.776448828693194, 2.9183308554571465, 3.4693205784270122, 11.640835880023797, 4.408310274930411, 6.903174114748873, 6.7450668192807965]
#
# Generación: 25
# Detalles de la asignación de procesos:
# Procesador 1 = 484
# Procesador 2 = 432
# Procesador 3 = 466
# Procesador 4 = 470
# Procesador 5 = 456
# Procesador 6 = 433
# Procesador 7 = 448
# Procesador 8 = 433
# Media de las cargas de procesadores: 455.125
# Mejor carga encontrada: 484
# Nueva población: [11.565584549567365, 7.565617743924555, 9.20889384744735, 12.220096145123824, 12.882319491222825, 7.019395165827139, 9.726207725248305, 15.954552040386705, 11.643604998702914, 4.8754845332806624, 12.012660279229175, 14.799260213719958, 8.733615939842831, 15.67348479297599, 7.875841198791787, 9.839291605962089]
#
# Generación: 26
# Detalles de la asignación de procesos:
# Procesador 1 = 413
# Procesador 2 = 451
# Procesador 3 = 437
# Procesador 4 = 473
# Procesador 5 = 480
# Procesador 6 = 450
# Procesador 7 = 448
# Procesador 8 = 453
# Media de las cargas de procesadores: 449.625
# Mejor carga encontrada: 480
# Nueva población: [1.5004413630448616, 15.346663322739644, 15.713920569202312, 11.559143752010712, 6.742366941434238, 4.056722700476824, 9.488172790314758, 10.061754260346799, 4.33394655127123, 12.342200213749967, 14.96408471093141, 10.221586762806423, 12.367454731992288, 11.683065664480706, 7.206617270665426, 3.0326097859476673]
#
# Generación: 27
# Detalles de la asignación de procesos:
# Procesador 1 = 473
# Procesador 2 = 463
# Procesador 3 = 450
# Procesador 4 = 484
# Procesador 5 = 459
# Procesador 6 = 429
# Procesador 7 = 443
# Procesador 8 = 454
# Media de las cargas de procesadores: 454.375
# Mejor carga encontrada: 484
# Nueva población: [5.796244930084202, 13.6937897885612, 3.50551449920935, 12.929663816759493, 14.853251195497222, 1.249490017715455, 6.161638765629194, 8.246331455085915, 11.938893079187274, 2.2428534373997087, 14.45363337815642, 12.988867951319794, 10.827683711563694, 9.139608445939812, 1.115449794001189, 2.3894153520471115]
#
# Generación: 28
# Detalles de la asignación de procesos:
# Procesador 1 = 445
# Procesador 2 = 460
# Procesador 3 = 456
# Procesador 4 = 484
# Procesador 5 = 438
# Procesador 6 = 443
# Procesador 7 = 456
# Procesador 8 = 443
# Media de las cargas de procesadores: 459.25
# Mejor carga encontrada: 484
# Nueva población: [2.4394804261034313, 6.811613522929423, 14.68386345644931, 11.190040180124242, 9.463767541005183, 6.640738705454166, 8.593580428175551, 6.260066020707344, 1.5261897187727187, 3.4135763747582932, 14.506832364916988, 11.020686297634123, 8.40813710157289, 1.0798418235111542, 11.300926292680446, 1.810455457361488]
#
# Generación: 29
# Detalles de la asignación de procesos:
# Procesador 1 = 470
# Procesador 2 = 454
# Procesador 3 = 455
# Procesador 4 = 484
# Procesador 5 = 470
# Procesador 6 = 473
# Procesador 7 = 464
# Procesador 8 = 473
# Media de las cargas de procesadores: 448.875
# Mejor carga encontrada: 484
# Nueva población: [12.387850490520567, 5.728159841634807, 9.736064904422584, 12.025308148091522, 12.50897388821156, 10.164716336212738, 3.4910111052473205, 11.300054237572567, 14.546240525915008, 13.46809828580386, 10.078920074040624, 12.293358738490978, 14.681501325797027, 12.54886727486809, 12.328095287933419, 10.966214567842512]
#
# Generación: 30
# Detalles de la asignación de procesos:
# Procesador 1 = 442
# Procesador 2 = 460
# Procesador 3 = 462
# Procesador 4 = 427
# Procesador 5 = 466
# Procesador 6 = 429
# Procesador 7 = 482
# Procesador 8 = 470
# Media de las cargas de procesadores: 453.75
# Mejor carga encontrada: 482
# Nueva población: [8.738189412984575, 3.944105035415258, 9.509970179776426, 3.344711845168639, 9.988585882964845, 1.2289844274239479, 12.487552034518243, 12.651517017739469, 14.989983643964846, 6.83190043510532, 6.029682254429798, 1.5106800297646115, 11.014879686216847, 7.627403485151719, 2.110332918447792, 14.854027422055687]
#
# Generación: 31
# Detalles de la asignación de procesos:
# Procesador 1 = 436
# Procesador 2 = 445
# Procesador 3 = 439
# Procesador 4 = 484
# Procesador 5 = 440
# Procesador 6 = 450
# Procesador 7 = 450
# Procesador 8 = 453
# Media de las cargas de procesadores: 462.125
# Mejor carga encontrada: 484
# Nueva población: [8.968689847007294, 1.2760582218097496, 5.018466980493683, 12.597358557479769, 15.761154011213629, 11.907502174157644, 11.937233438430567, 3.0257395096469306, 3.417816936901505, 2.809927143396397, 4.469558631978748, 12.650079355673373, 5.502371302272727, 4.337889539915787, 4.9448734318902305, 5.096871522224896]
#
# Generación: 32
# Detalles de la asignación de procesos:
# Procesador 1 = 437
# Procesador 2 = 462
# Procesador 3 = 436
# Procesador 4 = 431
# Procesador 5 = 462
# Procesador 6 = 459
# Procesador 7 = 462
# Procesador 8 = 484
# Media de las cargas de procesadores: 458.5
# Mejor carga encontrada: 484
# Nueva población: [13.961693107554957, 6.375104067803454, 4.6770330215244, 13.1693717958661, 6.321622632254791, 5.290094931155422, 6.510879001416703, 12.999890527431933, 8.320591770540585, 7.747123863936299, 14.546936742280057, 4.686485558667895, 7.577225964729591, 14.06826325479315, 9.002602048285778, 11.691952221734871]
#
# Generación: 33
# Detalles de la asignación de procesos:
# Procesador 1 = 453
# Procesador 2 = 433
# Procesador 3 = 480
# Procesador 4 = 484
# Procesador 5 = 455
# Procesador 6 = 451
# Procesador 7 = 464
# Procesador 8 = 445
# Media de las cargas de procesadores: 451.0
# Mejor carga encontrada: 484
# Nueva población: [3.82466767706095, 15.611733394855214, 6.809243416759386, 12.137614053763727, 10.861377306009182, 13.163266954869426, 7.940000436201841, 13.358096289183644, 5.130832681695828, 7.734036450884389, 12.996295459265294, 12.3175274831303, 7.157003940985749, 14.012814583749565, 2.299910963269417, 3.258832168946326]
#
# Generación: 34
# Detalles de la asignación de procesos:
# Procesador 1 = 440
# Procesador 2 = 428
# Procesador 3 = 462
# Procesador 4 = 462
# Procesador 5 = 466
# Procesador 6 = 482
# Procesador 7 = 453
# Procesador 8 = 466
# Media de las cargas de procesadores: 447.125
# Mejor carga encontrada: 482
# Nueva población: [15.74119237706551, 13.908270703043886, 7.428111056086675, 10.297001103666187, 7.62266270381895, 2.8905492433053035, 5.372116413470598, 7.2181624493123, 10.18412530567342, 1.8414664927276239, 6.202521561202227, 5.846123445273686, 12.817537246687815, 12.487966861323283, 3.377004684952897, 11.939711942429437]
#
# Generación: 35
# Detalles de la asignación de procesos:
# Procesador 1 = 414
# Procesador 2 = 482
# Procesador 3 = 436
# Procesador 4 = 464
# Procesador 5 = 470
# Procesador 6 = 429
# Procesador 7 = 454
# Procesador 8 = 466
# Media de las cargas de procesadores: 454.125
# Mejor carga encontrada: 482
# Nueva población: [1.7069833480011605, 12.618335309159393, 3.7632504011949095, 2.0585095241333935, 14.920464139995861, 1.4039261515490677, 8.40952723373476, 9.767076695086793, 15.006276645153514, 2.0992981386183103, 8.148206958687034, 7.2759237864031086, 12.880553439951665, 7.257186049960551, 2.7142195896102312, 11.92791960752004]
#
# Generación: 36
# Detalles de la asignación de procesos:
# Procesador 1 = 484
# Procesador 2 = 462
# Procesador 3 = 437
# Procesador 4 = 450
# Procesador 5 = 470
# Procesador 6 = 413
# Procesador 7 = 462
# Procesador 8 = 440
# Media de las cargas de procesadores: 450.625
# Mejor carga encontrada: 484
# Nueva población: [11.069284947149718, 3.7275676261360604, 8.50467885472797, 3.615979947220385, 11.392716431168731, 1.9251631011405648, 10.14320061267349, 5.86004247696486, 12.024940892283801, 2.990768253880171, 13.820349983971475, 14.02541344296455, 14.874707656757918, 4.108524985559164, 5.863710588952801, 15.927306138069165]
#
# Generación: 37
# Detalles de la asignación de procesos:
# Procesador 1 = 450
# Procesador 2 = 482
# Procesador 3 = 484
# Procesador 4 = 447
# Procesador 5 = 469
# Procesador 6 = 478
# Procesador 7 = 455
# Procesador 8 = 482
# Media de las cargas de procesadores: 454.0
# Mejor carga encontrada: 484
# Nueva población: [3.8921352023424647, 11.06910619207077, 11.562093360857801, 13.19594950601669, 6.691555224216373, 2.395373639206386, 9.638992655790043, 2.994954854326747, 14.669456453565878, 2.654764373549082, 11.733602075703676, 7.888814209759453, 10.73221495355153, 6.925408186871076, 5.531213370433424, 12.332994997971708]
#
# Generación: 38
# Detalles de la asignación de procesos:
# Procesador 1 = 482
# Procesador 2 = 473
# Procesador 3 = 423
# Procesador 4 = 462
# Procesador 5 = 439
# Procesador 6 = 466
# Procesador 7 = 439
# Procesador 8 = 447
# Media de las cargas de procesadores: 454.0
# Mejor carga encontrada: 482
# Nueva población: [2.279057687968576, 5.435097665822633, 15.31327467251919, 6.94653743475302, 4.630491770467732, 12.073712852092312, 4.736441030988313, 7.68275609269321, 11.963764746777752, 12.500772530686298, 8.365956081623644, 9.103908648415247, 5.567842620950611, 7.403439285933693, 10.514947515966798, 13.361836221928428]
#
# Generación: 39
# Detalles de la asignación de procesos:
# Procesador 1 = 429
# Procesador 2 = 466
# Procesador 3 = 456
# Procesador 4 = 423
# Procesador 5 = 484
# Procesador 6 = 451
# Procesador 7 = 482
# Procesador 8 = 427
# Media de las cargas de procesadores: 448.0
# Mejor carga encontrada: 484
# Nueva población: [9.929233105753324, 11.205438380275995, 8.628999482319692, 15.253673854112396, 12.622402484679714, 15.37396473391262, 12.545333058383443, 1.2888312372730168, 1.9803678132338605, 7.399980170398734, 12.512812907019207, 8.762856483189683, 12.596097989545072, 11.649437978622208, 2.4533965341438537, 3.122102111840456]
#
# Generación: 40
# Detalles de la asignación de procesos:
# Procesador 1 = 433
# Procesador 2 = 484
# Procesador 3 = 473
# Procesador 4 = 450
# Procesador 5 = 452
# Procesador 6 = 455
# Procesador 7 = 446
# Procesador 8 = 480
# Media de las cargas de procesadores: 446.375
# Mejor carga encontrada: 484
# Nueva población: [1.8390484212938087, 12.07355912655841, 12.554097659313229, 11.513259397204559, 14.606719955935223, 5.786475278478079, 6.421197398453627, 11.575858204929247, 14.51686087294838, 12.725778799673003, 5.10943607647382, 4.021102507758377, 9.145254453305203, 9.564293389206552, 4.391957356136116, 6.568774304390648]
#
# Generación: 41
# Detalles de la asignación de procesos:
# Procesador 1 = 466
# Procesador 2 = 468
# Procesador 3 = 466
# Procesador 4 = 413
# Procesador 5 = 450
# Procesador 6 = 484
# Procesador 7 = 433
# Procesador 8 = 468
# Media de las cargas de procesadores: 459.0
# Mejor carga encontrada: 484
# Nueva población: [7.662672772216384, 2.660569544860384, 7.607566827499817, 1.1504635320480352, 14.754929536087243, 12.163685620534835, 9.108036794061439, 2.1068283230222526, 12.827590172612723, 14.023675908109748, 11.76611145342738, 4.970739377286235, 3.566287361209685, 12.67997166031562, 15.785657603018457, 14.79407810678793]
#
# Generación: 42
# Detalles de la asignación de procesos:
# Procesador 1 = 482
# Procesador 2 = 436
# Procesador 3 = 456
# Procesador 4 = 464
# Procesador 5 = 432
# Procesador 6 = 450
# Procesador 7 = 462
# Procesador 8 = 455
# Media de las cargas de procesadores: 450.375
# Mejor carga encontrada: 482
# Nueva población: [2.7951912571400475, 5.6130667685309055, 8.299703210619464, 9.93788580746044, 4.298988386767887, 12.001350086364967, 10.334712817544972, 10.82534749242915, 12.221107652710774, 1.4573145591847394, 12.872078173354856, 2.41645224084243, 7.6388868845033535, 4.694807232255375, 5.86466784610894, 7.521118462746681]
#
# Generación: 43
# Detalles de la asignación de procesos:
# Procesador 1 = 454
# Procesador 2 = 466
# Procesador 3 = 432
# Procesador 4 = 480
# Procesador 5 = 484
# Procesador 6 = 462
# Procesador 7 = 466
# Procesador 8 = 473
# Media de las cargas de procesadores: 444.0
# Mejor carga encontrada: 484
# Nueva población: [13.646335850148889, 9.306835139238311, 13.773435697205917, 11.294141840267843, 11.389983622468252, 10.342380125251346, 9.559427858328183, 11.106316571875798, 5.0374637998577745, 11.817910342835834, 15.253897382436614, 6.265202176135267, 12.055997204238492, 10.409861946267428, 12.655688181798567, 10.081785288279423]
#
# Generación: 44
# Detalles de la asignación de procesos:
# Procesador 1 = 471
# Procesador 2 = 410
# Procesador 3 = 433
# Procesador 4 = 445
# Procesador 5 = 468
# Procesador 6 = 433
# Procesador 7 = 443
# Procesador 8 = 484
# Media de las cargas de procesadores: 457.875
# Mejor carga encontrada: 484
# Nueva población: [10.704982389090821, 1.0555684891752184, 9.685394646798784, 2.3192209687402583, 14.631257289800459, 14.189921754898496, 1.9133806122363874, 12.286331133851373, 2.942278728303134, 1.5645044303763784, 15.426896092466768, 1.201243383144043, 2.074139225073383, 1.8852616942206326, 6.096034548445499, 12.281983549558804]
#
# Generación: 45
# Detalles de la asignación de procesos:
# Procesador 1 = 455
# Procesador 2 = 432
# Procesador 3 = 471
# Procesador 4 = 482
# Procesador 5 = 448
# Procesador 6 = 446
# Procesador 7 = 480
# Procesador 8 = 462
# Media de las cargas de procesadores: 454.75
# Mejor carga encontrada: 482
# Nueva población: [5.724752234972528, 4.753876303468485, 2.1918577727632673, 11.986368911459222, 7.681308291706066, 6.172713939855162, 12.469750269237974, 9.211314032251138, 9.849468534850336, 7.4029706383278455, 10.171586569516538, 2.99148808065015, 9.135545241132286, 4.813393584745816, 6.4924245640877345, 6.874379808983588]
#
# Generación: 46
# Detalles de la asignación de procesos:
# Procesador 1 = 484
# Procesador 2 = 446
# Procesador 3 = 439
# Procesador 4 = 437
# Procesador 5 = 466
# Procesador 6 = 445
# Procesador 7 = 433
# Procesador 8 = 436
# Media de las cargas de procesadores: 441.375
# Mejor carga encontrada: 484
# Nueva población: [11.702400077849708, 7.476349297376476, 10.794199070194809, 8.041394103721409, 14.5593115162099, 8.47589733083973, 14.848460464966903, 5.259248674641435, 11.354867648051043, 3.961985170609535, 4.320940525167766, 13.056276971268758, 6.685651537795062, 10.387743577315174, 1.4280449265201203, 1.258195739748458]
#
# Generación: 47
# Detalles de la asignación de procesos:
# Procesador 1 = 482
# Procesador 2 = 447
# Procesador 3 = 471
# Procesador 4 = 465
# Procesador 5 = 437
# Procesador 6 = 484
# Procesador 7 = 464
# Procesador 8 = 473
# Media de las cargas de procesadores: 454.5
# Mejor carga encontrada: 484
# Nueva población: [2.6746681536208827, 12.553912713026374, 5.858639336418309, 11.312431815063439, 14.744017631123208, 12.638422046146763, 2.4573317041047447, 5.376898416379078, 11.704101948201755, 1.178957964854356, 2.0383154973183695, 13.545761996526263, 15.61966403536584, 12.141893546858832, 9.531804001794956, 11.800914036338295]
#
# Generación: 48
# Detalles de la asignación de procesos:
# Procesador 1 = 448
# Procesador 2 = 446
# Procesador 3 = 473
# Procesador 4 = 427
# Procesador 5 = 437
# Procesador 6 = 464
# Procesador 7 = 484
# Procesador 8 = 429
# Media de las cargas de procesadores: 435.125
# Mejor carga encontrada: 484
# Nueva población: [7.357351623940567, 4.60043215925464, 11.40196146387075, 1.4658651456927094, 15.255644530734862, 9.60698447609265, 11.74167414080876, 1.804611676012842, 9.787755704398501, 6.534006511545316, 5.1232129281452545, 3.6550323542852547, 14.993239126198887, 2.964857841826722, 12.475939565138194, 9.564491976620719]
#
# Generación: 49
# Detalles de la asignación de procesos:
# Procesador 1 = 464
# Procesador 2 = 416
# Procesador 3 = 480
# Procesador 4 = 414
# Procesador 5 = 462
# Procesador 6 = 449
# Procesador 7 = 469
# Procesador 8 = 440
# Media de las cargas de procesadores: 445.75
# Mejor carga encontrada: 480
# Nueva población: [7.691422548847586, 4.336236834073043, 6.281182769641749, 1.4064093566919857, 9.203564855996412, 2.615427043747974, 10.176759633078802, 15.912292805026535, 2.8207683753384067, 4.4698594723933445, 12.5965131688424, 15.684698826826521, 6.430994342209497, 15.783351921741591, 6.6468750304919055, 5.0477445537510235]
#
# Generación: 50
# Detalles de la asignación de procesos:
# Procesador 1 = 484
# Procesador 2 = 452
# Procesador 3 = 432
# Procesador 4 = 442
# Procesador 5 = 433
# Procesador 6 = 462
# Procesador 7 = 443
# Procesador 8 = 464
# Media de las cargas de procesadores: 451.875
# Mejor carga encontrada: 484
# Nueva población: [12.08601255867345, 6.432522281625943, 4.5380292075516095, 14.085680944049676, 7.926014438170416, 7.008936784827518, 6.776930768171721, 2.771519022765161, 12.317966115461745, 8.265053053038645, 7.634649108841789, 8.56501573789254, 15.707043275736444, 6.9805842674972745, 1.6760404630293226, 9.777333833294682]
